# %%
import numpy as np
from skimage import data, io
import matplotlib.pyplot as plt
import matplotlib.image as im
import os
# %matplotlib inline
os.getcwd()
os.chdir('C:/Users/Hector Garcia/Desktop/Camera_T02')
os.getcwd()
# Out:
# 'C:\\Users\\Hector Garcia\\Desktop\\Camera_T02'

# %%
n = 47
image = []
for i in np.arange(n):
    image.append(data.load('C:/Users/Hector Garcia/Desktop/Camera_T02/'+str(i)+'.jpg'))

# %%
#print(len(image))
#print(type(image))
avIm = np.sum(image, axis = 0) / n
aveIm = avIm.astype(np.uint8)
#print(avIm)
#plt.imshow(avIm)

# %%
aveIm = aveIm.astype(np.uint8)
im.imsave("ave.png", aveIm, format = 'png')

# %%
aux = 0
for j in np.arange(n):
    aux += np.square(avIm - image[j])
aux = aux / (n - 1)
stDev = np.sqrt(aux)
print(stDev)
# Out:
# [[[0.         0.         0.        ]
#   [0.         0.         0.        ]
#   [0.         0.         0.        ]
#   ...
#   [7.82037    4.8296609  5.06799283]
#   [7.64099659 5.58236618 5.18331844]
#   [7.24284712 5.02537502 5.41582633]]
#
#  [[0.         0.         0.        ]
#   [0.         0.         0.        ]
#   [0.         0.         0.        ]
#   ...
#   [7.35117528 5.39246056 6.06845013]
#   [6.56392462 4.9983346  5.40813448]
#   [7.08505221 5.95348917 6.31518734]]
#
#  [[0.         0.         0.        ]
#   [0.         0.         0.        ]
#   [0.         0.         0.        ]
#   ...
#   [7.21251354 4.53407288 5.59610344]
#   [7.05141682 4.37711228 5.65546407]
#   [8.3985484  6.09992342 7.11800885]]
#
#  ...
#
#  [[3.11838569 2.86546956 2.81925453]
#   [3.50946915 3.46049464 3.75646221]
#   [2.95557611 2.94302983 3.41934963]
#   ...
#   [3.53245819 3.0399742  4.11738041]
#   [3.12298038 3.22900248 4.36314139]
#   [3.75757022 4.00219644 5.391088  ]]
#
#  [[3.59861727 3.04179946 3.36645585]
#   [3.84433459 3.27225886 3.88538379]
#   [3.25255183 2.86369343 3.85406786]
#   ...
#   [3.59244247 3.24984878 4.05364125]
#   [3.46703786 3.45728527 4.32256305]
#   [4.23008475 4.50911298 5.26679508]]
#
#  [[3.04255966 2.520407   3.48977627]
#   [4.12893492 3.60619264 4.31109834]
#   [3.29872568 2.91110986 3.5412202 ]
#   ...
#   [3.69463446 3.76285954 4.69258474]
#   [3.16052198 2.94758403 3.96445819]
#   [4.03511414 3.61003842 4.50480266]]]

# %%
stDev = stDev.astype(np.uint8)
plt.imshow(stDev)
im.imsave("ImStDev.png", stDev, format = 'png')
#plt.savefig('foo.png')

# %%
print(stDev)
# Out:
# [[[0 0 0]
#   [0 0 0]
#   [0 0 0]
#   ...
#   [7 4 5]
#   [7 5 5]
#   [7 5 5]]
#
#  [[0 0 0]
#   [0 0 0]
#   [0 0 0]
#   ...
#   [7 5 6]
#   [6 4 5]
#   [7 5 6]]
#
#  [[0 0 0]
#   [0 0 0]
#   [0 0 0]
#   ...
#   [7 4 5]
#   [7 4 5]
#   [8 6 7]]
#
#  ...
#
#  [[3 2 2]
#   [3 3 3]
#   [2 2 3]
#   ...
#   [3 3 4]
#   [3 3 4]
#   [3 4 5]]
#
#  [[3 3 3]
#   [3 3 3]
#   [3 2 3]
#   ...
#   [3 3 4]
#   [3 3 4]
#   [4 4 5]]
#
#  [[3 2 3]
#   [4 3 4]
#   [3 2 3]
#   ...
#   [3 3 4]
#   [3 2 3]
#   [4 3 4]]]
